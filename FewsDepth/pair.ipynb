# %%
import os
from PIL import Image
import numpy as np
import open3d as o3d
import cv2
from scipy.linalg import svd
import kornia
import torch
from unidepth.utils import colorize, image_grid
from unidepth.models import UniDepthV1
from unidepth.utils.visualization import save_file_ply, colorize_np

from os import listdir
from os.path import join
from unidepth.utils.geometric import project_points
from poselib import estimate_relative_pose
from kornia_moons.viz import draw_LAF_matches
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def apply_intrinsics(points, intrinsics):
    my_intrinsics = {'fx': intrinsics[0][0],
                    'fy': intrinsics[1][1],
                    'cx': intrinsics[0][2],
                    'cy': intrinsics[1][2], }
    x = points[:, 0]
    y = points[:, 1]
    z = points[:, 2]

    z = z  
    x = (x - my_intrinsics['cx']) * z / my_intrinsics['fx']
    y = (y - my_intrinsics['cy']) * z / my_intrinsics['fy']
    #print(x.shape)
    final = np.hstack((x.reshape(-1, 1), y.reshape(-1, 1), z.reshape(-1, 1)))
    #print(final.shape)
    return final

# %%
def estimate_initial_transform(source_points, target_points):
    Rt, scale = cv2.estimateAffine3D(source_points, target_points, force_rotation=True)
    print(scale)
    return Rt, scale

def compose_transform_matrix(Rt):
    row_to_add = np.array([0, 0, 0, 1])
    transform_matrix = np.vstack([Rt, row_to_add])
    return transform_matrix

# %%
def pairwise_pose(img1_path, img2_path, model):

    img1 = kornia.io.load_image(img1_path, kornia.io.ImageLoadType.RGB32)[None, ...]
    img2 = kornia.io.load_image(img2_path, kornia.io.ImageLoadType.RGB32)[None, ...]
    matcher = kornia.feature.LoFTR(pretrained="indoor")
    input_dict = {
        "image0": kornia.color.rgb_to_grayscale(img1),  # LofTR works on grayscale images only
        "image1": kornia.color.rgb_to_grayscale(img2),
    }
    
    with torch.inference_mode():
        correspondences = matcher(input_dict)

    mkpts1 = correspondences["keypoints0"].cpu().numpy()
    mkpts2 = correspondences["keypoints1"].cpu().numpy()

    #depth1 = np.load('im1depth.npy')
    #depth2 = np.load('im2depth.npy')

    rgb = np.array(Image.open(img1_path))
    rgb_torch = torch.from_numpy(rgb).permute(2, 0, 1)
    predictions = model.infer(rgb_torch)
    depth1 = predictions["depth"].squeeze().cpu().numpy()
    
    np.save('im1depth', depth1)
    H, W = rgb.shape[:2]
    points = predictions["points"].squeeze().cpu().permute(1,2,0).numpy().reshape(H*W, 3)
    new_rgb = rgb.reshape(H*W, 3)
    file = "ply2/im1.ply"
    save_file_ply(points, new_rgb, file)
    intrinsics1 = predictions["intrinsics"].squeeze().cpu().numpy()
    torch_intrinsic1 = predictions["intrinsics"]
    torch_pts1 = predictions["points"]

    rgb = np.array(Image.open(img2_path))
    rgb_torch = torch.from_numpy(rgb).permute(2, 0, 1)
    predictions = model.infer(rgb_torch)
    depth2 = predictions["depth"].squeeze().cpu().numpy()
    np.save('im2depth', depth2)
    H, W = rgb.shape[:2]
    points = predictions["points"].squeeze().cpu().permute(1,2,0).numpy().reshape(H*W, 3)
    new_rgb = rgb.reshape(H*W, 3)
    file = "ply2/im2.ply"
    save_file_ply(points, new_rgb, file)
    intrinsics2 = predictions["intrinsics"].squeeze().cpu().numpy()

    corresponding_points_3d_img1 = np.zeros((len(mkpts1), 3))
    for i, (x, y) in enumerate(mkpts1):
        depth = depth1[int(y), int(x)]
        corresponding_points_3d_img1[i] = [x, y, depth]
    
    corresponding_points_3d_img2 = np.zeros((len(mkpts2), 3))
    for i, (x, y) in enumerate(mkpts2):
        depth = depth2[int(y), int(x)]
        corresponding_points_3d_img2[i] = [x, y, depth]

    #print('Before intrinsics:', corresponding_points_3d_img1)
    #print('After intrinsics:', apply_intrinsics(corresponding_points_3d_img1, intrinsics1))
    
    cp1 = apply_intrinsics(corresponding_points_3d_img1, intrinsics1)
    cp2 = apply_intrinsics(corresponding_points_3d_img2, intrinsics2)

    Rt, scale = estimate_initial_transform(cp2, cp1)
   
  #  camera1 = {'model': 'SIMPLE_PINHOLE', 'width': 736, 'height': 468, 'params': [intrinsics1[0][0], intrinsics1[1][1],  intrinsics1[0][2],  intrinsics1[1][2]]}
  #  camera2 = {'model': 'SIMPLE_PINHOLE', 'width': 736, 'height': 468, 'params': [intrinsics2[0][0], intrinsics2[1][1],  intrinsics2[0][2],  intrinsics2[1][2]]}

  #  Rt2 = estimate_relative_pose(mkpts2, mkpts1, camera2, camera1)

    initial_transform_matrix = compose_transform_matrix(Rt)
    #print(initial_transform_matrix)


    return initial_transform_matrix, scale, torch_intrinsic1, torch_pts1

# %%
def create_depth_map(pointcloud, intrinsics_matrix, image_shape):
    # Project 3D points onto image plane
    projected_points, _ = cv2.projectPoints(pointcloud, np.eye(3), np.zeros(3), intrinsics_matrix, None)
    H, W = image_shape
    # Initialize depth map and count map
    depth_map = [[[] for _ in range(W)] for _ in range(H)]


    # Aggregate depth values that project to the same pixel
    for i, point in enumerate(projected_points):
        x, y = point.ravel()
        z = pointcloud[i, 2]

        if 0 <= x < image_shape[1] and 0 <= y < image_shape[0]:
            depth_map[int(y)][int(x)].append(z)
    
    final_depth = np.zeros(image_shape)

    m = 0.5
    for i in range(H):
        for j in range(W):
            data = np.array(depth_map[i][j])
            #if len(data) < 3:
            #    final_depth[i][j] = np.mean(data)
            #    continue
            #data = data[abs(data - np.mean(data)) < m * np.std(data)]
            median = np.median(data)
            final_depth[i][j] = median if median != np.NaN else 0

    return final_depth

# %%
def preprocess_point_cloud(pcd, voxel_size):
    print(":: Downsample with a voxel size %.3f." % voxel_size)
    pcd_down = pcd.voxel_down_sample(voxel_size)

    radius_normal = voxel_size * 2
    print(":: Estimate normal with search radius %.3f." % radius_normal)
    pcd_down.estimate_normals(
        o3d.geometry.KDTreeSearchParamHybrid(radius=radius_normal, max_nn=30))

    radius_feature = voxel_size * 5
    print(":: Compute FPFH feature with search radius %.3f." % radius_feature)
    pcd_fpfh = o3d.pipelines.registration.compute_fpfh_feature(
        pcd_down,
        o3d.geometry.KDTreeSearchParamHybrid(radius=radius_feature, max_nn=100))
    return pcd_down, pcd_fpfh

# %%
def pairwise_registration(source, target, max_correspondence_distance_coarse, max_correspondence_distance_fine):
    print("Apply point-to-plane ICP")
    icp_coarse = o3d.pipelines.registration.registration_icp(
        source, target, max_correspondence_distance_coarse, np.identity(4),
        o3d.pipelines.registration.TransformationEstimationPointToPlane())
    icp_fine = o3d.pipelines.registration.registration_icp(
        source, target, max_correspondence_distance_fine,
        icp_coarse.transformation,
        o3d.pipelines.registration.TransformationEstimationPointToPlane())
    transformation_icp = icp_fine.transformation
    information_icp = o3d.pipelines.registration.get_information_matrix_from_point_clouds(
        source, target, max_correspondence_distance_fine,
        icp_fine.transformation)
    return transformation_icp, information_icp


def full_registration(pcds, max_correspondence_distance_coarse,
                      max_correspondence_distance_fine):
    pose_graph = o3d.pipelines.registration.PoseGraph()
    odometry = np.identity(4)
    pose_graph.nodes.append(o3d.pipelines.registration.PoseGraphNode(odometry))
    n_pcds = len(pcds)
    for source_id in range(n_pcds):
        for target_id in range(source_id + 1, n_pcds):
            transformation_icp, information_icp = pairwise_registration(
                pcds[source_id], pcds[target_id], max_correspondence_distance_coarse, max_correspondence_distance_fine)
            print("Build o3d.pipelines.registration.PoseGraph")
            if target_id == source_id + 1:  # odometry case
                odometry = np.dot(transformation_icp, odometry)
                pose_graph.nodes.append(
                    o3d.pipelines.registration.PoseGraphNode(
                        np.linalg.inv(odometry)))
                pose_graph.edges.append(
                    o3d.pipelines.registration.PoseGraphEdge(source_id,
                                                             target_id,
                                                             transformation_icp,
                                                             information_icp,
                                                             uncertain=False))
            else:  # loop closure case
                pose_graph.edges.append(
                    o3d.pipelines.registration.PoseGraphEdge(source_id,
                                                             target_id,
                                                             transformation_icp,
                                                             information_icp,
                                                             uncertain=True))
    return pose_graph

# %%
from os import listdir
from os.path import join
import matplotlib.pyplot as plt
import copy

model = UniDepthV1.from_pretrained("lpiccinelli/unidepth-v1-vitl14")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

base_path = "base.png"
H,W  = np.array(Image.open(base_path)).shape[:2]

support_paths = []
for filename in listdir("supports"): 
    full_path = join("supports", filename)
    support_paths.append(full_path)


sup_pcds = []
for i, sup_path in enumerate(support_paths):
    T, scale, torch_intrinsics1, torch_points1 = pairwise_pose(base_path, sup_path, model) # base, sup order
    if scale > 1.1 or scale < 0.9:
        continue
    pcd1 = o3d.io.read_point_cloud("ply2/im1.ply")
    pcd2 = o3d.io.read_point_cloud("ply2/im2.ply")
    pcd2 = pcd2.scale(scale, center=(0, 0, 0))
    pcd2 = pcd2.transform(T)
    o3d.io.write_point_cloud(f"ply2/{i}.ply", pcd2)
    sup_pcds.append(pcd2)
   # os.remove("ply2/im1.ply")
   # os.remove("ply2/im2.ply")
# Out:
# Instantiate: dinov2_vitl14
# 0.9009178792806232
# 0.965194057866866
# 0.8596963478058745
# 0.9371253863070599
# 0.9117820714885012
# 0.9887373985294833
# 0.9226117237632034
# 0.846606878894724
# 0.9175268212750732
# 0.926433878167816
# 0.9539395769125829
# 0.9356813544818373
# 0.8907997893182353
# 0.9640348736512001
# 0.940428687178831
# 0.9672434315076213
# 0.9363565682915794
# 0.9740852097422532
# 1.0001081578176478
# 0.9006157704575346
# 0.9783318680773828
# 0.9406879540022874
# 0.8730625535236296
# 0.9687147521524532
# 0.9758516382683653
# 1.0226290750290676

# %%
voxel_size = 0.02
pcds_down = []
for pcd in sup_pcds:
    pcd_down = pcd.voxel_down_sample(voxel_size=voxel_size)
    radius_normal = voxel_size * 2
    pcd_down.estimate_normals(o3d.geometry.KDTreeSearchParamHybrid(radius=radius_normal, max_nn=30))
    pcds_down.append(pcd_down)

print("Full registration ...")
max_correspondence_distance_coarse = voxel_size * 15
max_correspondence_distance_fine = voxel_size * 1.5
with o3d.utility.VerbosityContextManager(
        o3d.utility.VerbosityLevel.Debug) as cm:
    pose_graph = full_registration(pcds_down,
                                   max_correspondence_distance_coarse,
                                   max_correspondence_distance_fine)

print("Optimizing PoseGraph ...")
option = o3d.pipelines.registration.GlobalOptimizationOption(
    max_correspondence_distance=max_correspondence_distance_fine,
    edge_prune_threshold=0.25,
    reference_node=0)
with o3d.utility.VerbosityContextManager(
        o3d.utility.VerbosityLevel.Debug) as cm:
    o3d.pipelines.registration.global_optimization(
        pose_graph,
        o3d.pipelines.registration.GlobalOptimizationLevenbergMarquardt(),
        o3d.pipelines.registration.GlobalOptimizationConvergenceCriteria(),
        option)

print("Transform points and display")
for point_id in range(len(pcds_down)):
    print(pose_graph.nodes[point_id].pose)
    pcds_down[point_id].transform(pose_graph.nodes[point_id].pose)
# Out:
# Full registration ...
# Apply point-to-plane ICP
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.5990, RMSE 0.1423
# [Open3D DEBUG] Residual : 1.46e-02 (# of elements : 132195)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.6768, RMSE 0.1314
# [Open3D DEBUG] Residual : 1.31e-02 (# of elements : 149374)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.6760, RMSE 0.1046
# [Open3D DEBUG] Residual : 7.09e-03 (# of elements : 149195)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.6721, RMSE 0.0966
# [Open3D DEBUG] Residual : 5.54e-03 (# of elements : 148334)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.6696, RMSE 0.0944
# [Open3D DEBUG] Residual : 5.17e-03 (# of elements : 147782)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.6680, RMSE 0.0935
# [Open3D DEBUG] Residual : 5.03e-03 (# of elements : 147427)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.6667, RMSE 0.0930
# [Open3D DEBUG] Residual : 4.96e-03 (# of elements : 147154)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.6659, RMSE 0.0928
# [Open3D DEBUG] Residual : 4.94e-03 (# of elements : 146975)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.6654, RMSE 0.0927
# [Open3D DEBUG] Residual : 4.93e-03 (# of elements : 146857)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.6650, RMSE 0.0926
# [Open3D DEBUG] Residual : 4.93e-03 (# of elements : 146775)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.6648, RMSE 0.0926
# [Open3D DEBUG] Residual : 4.93e-03 (# of elements : 146721)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.6646, RMSE 0.0926
# [Open3D DEBUG] Residual : 4.94e-03 (# of elements : 146686)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.6645, RMSE 0.0926
# [Open3D DEBUG] Residual : 4.93e-03 (# of elements : 146666)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.6644, RMSE 0.0926
# [Open3D DEBUG] Residual : 4.93e-03 (# of elements : 146640)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.6644, RMSE 0.0926
# [Open3D DEBUG] Residual : 4.93e-03 (# of elements : 146632)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.6643, RMSE 0.0926
# [Open3D DEBUG] Residual : 4.94e-03 (# of elements : 146621)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.6643, RMSE 0.0926
# [Open3D DEBUG] Residual : 4.93e-03 (# of elements : 146615)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.6643, RMSE 0.0926
# [Open3D DEBUG] Residual : 4.93e-03 (# of elements : 146614)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.6643, RMSE 0.0926
# [Open3D DEBUG] Residual : 4.93e-03 (# of elements : 146616)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.6643, RMSE 0.0926
# [Open3D DEBUG] Residual : 4.93e-03 (# of elements : 146617)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.6643, RMSE 0.0926
# [Open3D DEBUG] Residual : 4.93e-03 (# of elements : 146617)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.6643, RMSE 0.0926
# [Open3D DEBUG] Residual : 4.93e-03 (# of elements : 146617)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.6643, RMSE 0.0926
# [Open3D DEBUG] Residual : 4.93e-03 (# of elements : 146617)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.6643, RMSE 0.0926
# [Open3D DEBUG] Residual : 4.94e-03 (# of elements : 146617)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.1962, RMSE 0.0200
# [Open3D DEBUG] Residual : 2.37e-04 (# of elements : 43300)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.2087, RMSE 0.0196
# [Open3D DEBUG] Residual : 2.22e-04 (# of elements : 46059)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.2107, RMSE 0.0194
# [Open3D DEBUG] Residual : 2.13e-04 (# of elements : 46507)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.2115, RMSE 0.0193
# [Open3D DEBUG] Residual : 2.07e-04 (# of elements : 46690)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.2118, RMSE 0.0191
# [Open3D DEBUG] Residual : 2.04e-04 (# of elements : 46736)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.2123, RMSE 0.0190
# [Open3D DEBUG] Residual : 2.03e-04 (# of elements : 46853)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.2126, RMSE 0.0189
# [Open3D DEBUG] Residual : 2.01e-04 (# of elements : 46927)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.2129, RMSE 0.0188
# [Open3D DEBUG] Residual : 2.00e-04 (# of elements : 46993)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.2129, RMSE 0.0189
# [Open3D DEBUG] Residual : 1.97e-04 (# of elements : 46984)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.2122, RMSE 0.0189
# [Open3D DEBUG] Residual : 1.94e-04 (# of elements : 46824)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.2121, RMSE 0.0186
# [Open3D DEBUG] Residual : 1.91e-04 (# of elements : 46804)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.2123, RMSE 0.0184
# [Open3D DEBUG] Residual : 1.88e-04 (# of elements : 46862)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.2130, RMSE 0.0185
# [Open3D DEBUG] Residual : 1.85e-04 (# of elements : 47021)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.2144, RMSE 0.0185
# [Open3D DEBUG] Residual : 1.84e-04 (# of elements : 47318)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.2157, RMSE 0.0183
# [Open3D DEBUG] Residual : 1.84e-04 (# of elements : 47617)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.2172, RMSE 0.0184
# [Open3D DEBUG] Residual : 1.85e-04 (# of elements : 47944)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.2187, RMSE 0.0184
# [Open3D DEBUG] Residual : 1.85e-04 (# of elements : 48270)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.2196, RMSE 0.0182
# [Open3D DEBUG] Residual : 1.84e-04 (# of elements : 48471)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.2200, RMSE 0.0183
# [Open3D DEBUG] Residual : 1.83e-04 (# of elements : 48549)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.2204, RMSE 0.0182
# [Open3D DEBUG] Residual : 1.81e-04 (# of elements : 48651)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.2205, RMSE 0.0181
# [Open3D DEBUG] Residual : 1.80e-04 (# of elements : 48656)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.2206, RMSE 0.0181
# [Open3D DEBUG] Residual : 1.80e-04 (# of elements : 48693)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.2206, RMSE 0.0181
# [Open3D DEBUG] Residual : 1.79e-04 (# of elements : 48680)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.2201, RMSE 0.0180
# [Open3D DEBUG] Residual : 1.79e-04 (# of elements : 48585)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.2201, RMSE 0.0180
# [Open3D DEBUG] Residual : 1.78e-04 (# of elements : 48571)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.2196, RMSE 0.0180
# [Open3D DEBUG] Residual : 1.78e-04 (# of elements : 48476)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.2192, RMSE 0.0180
# [Open3D DEBUG] Residual : 1.77e-04 (# of elements : 48388)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.2190, RMSE 0.0180
# [Open3D DEBUG] Residual : 1.77e-04 (# of elements : 48339)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.2187, RMSE 0.0180
# [Open3D DEBUG] Residual : 1.76e-04 (# of elements : 48275)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.2184, RMSE 0.0180
# [Open3D DEBUG] Residual : 1.75e-04 (# of elements : 48196)
# Build o3d.pipelines.registration.PoseGraph
# Apply point-to-plane ICP
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.6971, RMSE 0.1346
# [Open3D DEBUG] Residual : 1.37e-02 (# of elements : 153856)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.7701, RMSE 0.1304
# [Open3D DEBUG] Residual : 1.34e-02 (# of elements : 169959)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.7663, RMSE 0.1109
# [Open3D DEBUG] Residual : 8.63e-03 (# of elements : 169128)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.7642, RMSE 0.1068
# [Open3D DEBUG] Residual : 7.64e-03 (# of elements : 168654)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.7632, RMSE 0.1060
# [Open3D DEBUG] Residual : 7.42e-03 (# of elements : 168453)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.7628, RMSE 0.1058
# [Open3D DEBUG] Residual : 7.38e-03 (# of elements : 168352)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.7623, RMSE 0.1057
# [Open3D DEBUG] Residual : 7.36e-03 (# of elements : 168236)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.7618, RMSE 0.1057
# [Open3D DEBUG] Residual : 7.38e-03 (# of elements : 168141)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.7614, RMSE 0.1057
# [Open3D DEBUG] Residual : 7.39e-03 (# of elements : 168042)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.7607, RMSE 0.1055
# [Open3D DEBUG] Residual : 7.39e-03 (# of elements : 167892)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.7601, RMSE 0.1054
# [Open3D DEBUG] Residual : 7.38e-03 (# of elements : 167760)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.7596, RMSE 0.1053
# [Open3D DEBUG] Residual : 7.37e-03 (# of elements : 167640)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.7591, RMSE 0.1052
# [Open3D DEBUG] Residual : 7.36e-03 (# of elements : 167536)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.7586, RMSE 0.1051
# [Open3D DEBUG] Residual : 7.35e-03 (# of elements : 167432)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.7582, RMSE 0.1050
# [Open3D DEBUG] Residual : 7.34e-03 (# of elements : 167343)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.7579, RMSE 0.1049
# [Open3D DEBUG] Residual : 7.33e-03 (# of elements : 167273)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.7576, RMSE 0.1049
# [Open3D DEBUG] Residual : 7.33e-03 (# of elements : 167200)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.7574, RMSE 0.1048
# [Open3D DEBUG] Residual : 7.33e-03 (# of elements : 167164)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.7572, RMSE 0.1048
# [Open3D DEBUG] Residual : 7.33e-03 (# of elements : 167122)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.7571, RMSE 0.1048
# [Open3D DEBUG] Residual : 7.33e-03 (# of elements : 167100)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.7570, RMSE 0.1048
# [Open3D DEBUG] Residual : 7.33e-03 (# of elements : 167071)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.7569, RMSE 0.1048
# [Open3D DEBUG] Residual : 7.33e-03 (# of elements : 167062)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.7569, RMSE 0.1048
# [Open3D DEBUG] Residual : 7.33e-03 (# of elements : 167049)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.7568, RMSE 0.1047
# [Open3D DEBUG] Residual : 7.33e-03 (# of elements : 167022)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.7567, RMSE 0.1047
# [Open3D DEBUG] Residual : 7.33e-03 (# of elements : 167009)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.7567, RMSE 0.1047
# [Open3D DEBUG] Residual : 7.32e-03 (# of elements : 166997)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.7566, RMSE 0.1047
# [Open3D DEBUG] Residual : 7.32e-03 (# of elements : 166992)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.7566, RMSE 0.1047
# [Open3D DEBUG] Residual : 7.32e-03 (# of elements : 166990)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.7566, RMSE 0.1047
# [Open3D DEBUG] Residual : 7.32e-03 (# of elements : 166982)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.7565, RMSE 0.1047
# [Open3D DEBUG] Residual : 7.32e-03 (# of elements : 166974)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.2088, RMSE 0.0202
# [Open3D DEBUG] Residual : 2.30e-04 (# of elements : 46076)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.2350, RMSE 0.0186
# [Open3D DEBUG] Residual : 1.78e-04 (# of elements : 51862)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.2365, RMSE 0.0182
# [Open3D DEBUG] Residual : 1.61e-04 (# of elements : 52200)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.2363, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.54e-04 (# of elements : 52159)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.2355, RMSE 0.0177
# [Open3D DEBUG] Residual : 1.48e-04 (# of elements : 51974)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.2350, RMSE 0.0177
# [Open3D DEBUG] Residual : 1.45e-04 (# of elements : 51863)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.2350, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.43e-04 (# of elements : 51857)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.2351, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.43e-04 (# of elements : 51883)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.2351, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.42e-04 (# of elements : 51893)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.2356, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.43e-04 (# of elements : 51995)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.2358, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.43e-04 (# of elements : 52040)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.2363, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.44e-04 (# of elements : 52156)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.2368, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.44e-04 (# of elements : 52262)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.2370, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.44e-04 (# of elements : 52302)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.2371, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.44e-04 (# of elements : 52334)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.2373, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.44e-04 (# of elements : 52384)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.2375, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.45e-04 (# of elements : 52422)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.2376, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.45e-04 (# of elements : 52447)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.2380, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.45e-04 (# of elements : 52517)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.2381, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.45e-04 (# of elements : 52540)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.2383, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.46e-04 (# of elements : 52586)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.2383, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.46e-04 (# of elements : 52603)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.2386, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.46e-04 (# of elements : 52653)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.2387, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.46e-04 (# of elements : 52681)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.2388, RMSE 0.0179
# [Open3D DEBUG] Residual : 1.46e-04 (# of elements : 52704)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.2389, RMSE 0.0179
# [Open3D DEBUG] Residual : 1.46e-04 (# of elements : 52718)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.2387, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.46e-04 (# of elements : 52688)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.2386, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.46e-04 (# of elements : 52661)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.2387, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.46e-04 (# of elements : 52683)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.2386, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.46e-04 (# of elements : 52665)
# Build o3d.pipelines.registration.PoseGraph
# Apply point-to-plane ICP
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.8609, RMSE 0.1061
# [Open3D DEBUG] Residual : 8.20e-03 (# of elements : 190006)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.8666, RMSE 0.0838
# [Open3D DEBUG] Residual : 4.53e-03 (# of elements : 191270)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.8671, RMSE 0.0814
# [Open3D DEBUG] Residual : 4.20e-03 (# of elements : 191384)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.8673, RMSE 0.0812
# [Open3D DEBUG] Residual : 4.18e-03 (# of elements : 191410)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.8673, RMSE 0.0812
# [Open3D DEBUG] Residual : 4.18e-03 (# of elements : 191416)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.8673, RMSE 0.0812
# [Open3D DEBUG] Residual : 4.18e-03 (# of elements : 191420)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.8673, RMSE 0.0812
# [Open3D DEBUG] Residual : 4.17e-03 (# of elements : 191421)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.8673, RMSE 0.0812
# [Open3D DEBUG] Residual : 4.17e-03 (# of elements : 191421)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.8673, RMSE 0.0812
# [Open3D DEBUG] Residual : 4.17e-03 (# of elements : 191422)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.8673, RMSE 0.0812
# [Open3D DEBUG] Residual : 4.18e-03 (# of elements : 191423)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.8673, RMSE 0.0812
# [Open3D DEBUG] Residual : 4.18e-03 (# of elements : 191423)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.3016, RMSE 0.0184
# [Open3D DEBUG] Residual : 1.68e-04 (# of elements : 66566)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.3063, RMSE 0.0177
# [Open3D DEBUG] Residual : 1.42e-04 (# of elements : 67591)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.3075, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.34e-04 (# of elements : 67871)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.3079, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.30e-04 (# of elements : 67951)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.3080, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.29e-04 (# of elements : 67972)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.3081, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.29e-04 (# of elements : 67991)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.3081, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.29e-04 (# of elements : 68003)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.3082, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.30e-04 (# of elements : 68014)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.3081, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.30e-04 (# of elements : 68010)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.3085, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.30e-04 (# of elements : 68080)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.3087, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.31e-04 (# of elements : 68125)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.3090, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.32e-04 (# of elements : 68193)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.3094, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.33e-04 (# of elements : 68281)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.3100, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.34e-04 (# of elements : 68426)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.3107, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.35e-04 (# of elements : 68566)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.3116, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.35e-04 (# of elements : 68764)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.3128, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.37e-04 (# of elements : 69027)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.3145, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.38e-04 (# of elements : 69412)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.3169, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.40e-04 (# of elements : 69946)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.3196, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.39e-04 (# of elements : 70546)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.3227, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.38e-04 (# of elements : 71225)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.3261, RMSE 0.0174
# [Open3D DEBUG] Residual : 1.37e-04 (# of elements : 71974)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.3283, RMSE 0.0173
# [Open3D DEBUG] Residual : 1.34e-04 (# of elements : 72466)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.3302, RMSE 0.0173
# [Open3D DEBUG] Residual : 1.32e-04 (# of elements : 72877)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.3318, RMSE 0.0173
# [Open3D DEBUG] Residual : 1.31e-04 (# of elements : 73233)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.3331, RMSE 0.0173
# [Open3D DEBUG] Residual : 1.31e-04 (# of elements : 73522)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.3335, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.31e-04 (# of elements : 73606)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.3346, RMSE 0.0173
# [Open3D DEBUG] Residual : 1.32e-04 (# of elements : 73848)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.3346, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.32e-04 (# of elements : 73839)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.3350, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.32e-04 (# of elements : 73943)
# Build o3d.pipelines.registration.PoseGraph
# Apply point-to-plane ICP
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.9007, RMSE 0.1253
# [Open3D DEBUG] Residual : 1.32e-02 (# of elements : 198780)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.9067, RMSE 0.1126
# [Open3D DEBUG] Residual : 1.01e-02 (# of elements : 200118)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.9028, RMSE 0.1101
# [Open3D DEBUG] Residual : 9.45e-03 (# of elements : 199246)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.9001, RMSE 0.1094
# [Open3D DEBUG] Residual : 9.25e-03 (# of elements : 198654)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.8984, RMSE 0.1091
# [Open3D DEBUG] Residual : 9.16e-03 (# of elements : 198283)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.8971, RMSE 0.1088
# [Open3D DEBUG] Residual : 9.09e-03 (# of elements : 197998)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.8964, RMSE 0.1087
# [Open3D DEBUG] Residual : 9.06e-03 (# of elements : 197840)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.8958, RMSE 0.1086
# [Open3D DEBUG] Residual : 9.04e-03 (# of elements : 197702)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.8954, RMSE 0.1085
# [Open3D DEBUG] Residual : 9.02e-03 (# of elements : 197616)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.8951, RMSE 0.1085
# [Open3D DEBUG] Residual : 9.01e-03 (# of elements : 197560)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.8949, RMSE 0.1084
# [Open3D DEBUG] Residual : 9.00e-03 (# of elements : 197519)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.8948, RMSE 0.1084
# [Open3D DEBUG] Residual : 9.00e-03 (# of elements : 197488)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.8947, RMSE 0.1084
# [Open3D DEBUG] Residual : 8.99e-03 (# of elements : 197462)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.8946, RMSE 0.1084
# [Open3D DEBUG] Residual : 8.99e-03 (# of elements : 197444)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.8946, RMSE 0.1084
# [Open3D DEBUG] Residual : 8.98e-03 (# of elements : 197435)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.8945, RMSE 0.1083
# [Open3D DEBUG] Residual : 8.98e-03 (# of elements : 197425)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.8945, RMSE 0.1083
# [Open3D DEBUG] Residual : 8.98e-03 (# of elements : 197423)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.1909, RMSE 0.0200
# [Open3D DEBUG] Residual : 2.52e-04 (# of elements : 42142)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.1985, RMSE 0.0190
# [Open3D DEBUG] Residual : 2.20e-04 (# of elements : 43804)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.2073, RMSE 0.0190
# [Open3D DEBUG] Residual : 2.19e-04 (# of elements : 45761)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.2160, RMSE 0.0189
# [Open3D DEBUG] Residual : 2.22e-04 (# of elements : 47663)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.2180, RMSE 0.0185
# [Open3D DEBUG] Residual : 2.11e-04 (# of elements : 48122)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.2206, RMSE 0.0184
# [Open3D DEBUG] Residual : 2.06e-04 (# of elements : 48679)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.2237, RMSE 0.0183
# [Open3D DEBUG] Residual : 2.04e-04 (# of elements : 49361)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.2258, RMSE 0.0182
# [Open3D DEBUG] Residual : 2.02e-04 (# of elements : 49826)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.2276, RMSE 0.0182
# [Open3D DEBUG] Residual : 2.00e-04 (# of elements : 50238)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.2299, RMSE 0.0181
# [Open3D DEBUG] Residual : 2.00e-04 (# of elements : 50743)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.2324, RMSE 0.0181
# [Open3D DEBUG] Residual : 1.98e-04 (# of elements : 51287)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.2332, RMSE 0.0180
# [Open3D DEBUG] Residual : 1.94e-04 (# of elements : 51477)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.2341, RMSE 0.0179
# [Open3D DEBUG] Residual : 1.90e-04 (# of elements : 51662)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.2351, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.87e-04 (# of elements : 51879)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.2361, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.86e-04 (# of elements : 52100)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.2364, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.85e-04 (# of elements : 52176)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.2360, RMSE 0.0177
# [Open3D DEBUG] Residual : 1.82e-04 (# of elements : 52092)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.2370, RMSE 0.0177
# [Open3D DEBUG] Residual : 1.81e-04 (# of elements : 52304)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.2386, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.81e-04 (# of elements : 52666)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.2402, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.78e-04 (# of elements : 53003)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.2414, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.73e-04 (# of elements : 53275)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.2436, RMSE 0.0174
# [Open3D DEBUG] Residual : 1.71e-04 (# of elements : 53759)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.2458, RMSE 0.0174
# [Open3D DEBUG] Residual : 1.67e-04 (# of elements : 54239)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.2476, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.61e-04 (# of elements : 54654)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.2503, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.56e-04 (# of elements : 55247)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.2521, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.52e-04 (# of elements : 55629)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.2529, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.48e-04 (# of elements : 55812)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.2534, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.47e-04 (# of elements : 55919)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.2533, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.45e-04 (# of elements : 55915)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.2534, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.45e-04 (# of elements : 55922)
# Build o3d.pipelines.registration.PoseGraph
# Apply point-to-plane ICP
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.7897, RMSE 0.1190
# [Open3D DEBUG] Residual : 1.06e-02 (# of elements : 174281)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.8060, RMSE 0.1028
# [Open3D DEBUG] Residual : 7.37e-03 (# of elements : 177896)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.8057, RMSE 0.0986
# [Open3D DEBUG] Residual : 6.65e-03 (# of elements : 177823)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.8045, RMSE 0.0971
# [Open3D DEBUG] Residual : 6.40e-03 (# of elements : 177547)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.8035, RMSE 0.0965
# [Open3D DEBUG] Residual : 6.32e-03 (# of elements : 177346)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.8030, RMSE 0.0963
# [Open3D DEBUG] Residual : 6.28e-03 (# of elements : 177219)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.8027, RMSE 0.0962
# [Open3D DEBUG] Residual : 6.27e-03 (# of elements : 177163)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.8025, RMSE 0.0962
# [Open3D DEBUG] Residual : 6.26e-03 (# of elements : 177122)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.8024, RMSE 0.0961
# [Open3D DEBUG] Residual : 6.26e-03 (# of elements : 177089)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.8023, RMSE 0.0961
# [Open3D DEBUG] Residual : 6.25e-03 (# of elements : 177065)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.8022, RMSE 0.0961
# [Open3D DEBUG] Residual : 6.25e-03 (# of elements : 177056)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.8022, RMSE 0.0961
# [Open3D DEBUG] Residual : 6.25e-03 (# of elements : 177052)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.8022, RMSE 0.0961
# [Open3D DEBUG] Residual : 6.25e-03 (# of elements : 177051)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.8022, RMSE 0.0961
# [Open3D DEBUG] Residual : 6.25e-03 (# of elements : 177050)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.8022, RMSE 0.0961
# [Open3D DEBUG] Residual : 6.25e-03 (# of elements : 177051)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.8022, RMSE 0.0961
# [Open3D DEBUG] Residual : 6.25e-03 (# of elements : 177049)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.8022, RMSE 0.0961
# [Open3D DEBUG] Residual : 6.25e-03 (# of elements : 177048)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.2090, RMSE 0.0189
# [Open3D DEBUG] Residual : 2.09e-04 (# of elements : 46118)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.2131, RMSE 0.0186
# [Open3D DEBUG] Residual : 1.97e-04 (# of elements : 47025)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.2161, RMSE 0.0182
# [Open3D DEBUG] Residual : 1.84e-04 (# of elements : 47705)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.2179, RMSE 0.0180
# [Open3D DEBUG] Residual : 1.73e-04 (# of elements : 48101)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.2189, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.66e-04 (# of elements : 48314)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.2202, RMSE 0.0177
# [Open3D DEBUG] Residual : 1.61e-04 (# of elements : 48601)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.2233, RMSE 0.0177
# [Open3D DEBUG] Residual : 1.58e-04 (# of elements : 49290)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.2275, RMSE 0.0177
# [Open3D DEBUG] Residual : 1.56e-04 (# of elements : 50217)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.2314, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.53e-04 (# of elements : 51061)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.2344, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.51e-04 (# of elements : 51726)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.2368, RMSE 0.0174
# [Open3D DEBUG] Residual : 1.50e-04 (# of elements : 52253)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.2381, RMSE 0.0174
# [Open3D DEBUG] Residual : 1.47e-04 (# of elements : 52560)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.2390, RMSE 0.0173
# [Open3D DEBUG] Residual : 1.46e-04 (# of elements : 52753)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.2396, RMSE 0.0173
# [Open3D DEBUG] Residual : 1.45e-04 (# of elements : 52872)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.2396, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.44e-04 (# of elements : 52887)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.2397, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.43e-04 (# of elements : 52910)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.2399, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.43e-04 (# of elements : 52941)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.2400, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.43e-04 (# of elements : 52969)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.2400, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.43e-04 (# of elements : 52962)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.2399, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.42e-04 (# of elements : 52957)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.2400, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.43e-04 (# of elements : 52978)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.2401, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.42e-04 (# of elements : 53001)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.2402, RMSE 0.0173
# [Open3D DEBUG] Residual : 1.42e-04 (# of elements : 53014)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.2404, RMSE 0.0173
# [Open3D DEBUG] Residual : 1.42e-04 (# of elements : 53047)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.2405, RMSE 0.0174
# [Open3D DEBUG] Residual : 1.42e-04 (# of elements : 53082)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.2405, RMSE 0.0174
# [Open3D DEBUG] Residual : 1.41e-04 (# of elements : 53085)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.2402, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.40e-04 (# of elements : 53017)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.2403, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.39e-04 (# of elements : 53046)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.2405, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.38e-04 (# of elements : 53075)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.2405, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.37e-04 (# of elements : 53084)
# Build o3d.pipelines.registration.PoseGraph
# Apply point-to-plane ICP
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.9070, RMSE 0.1051
# [Open3D DEBUG] Residual : 8.20e-03 (# of elements : 200189)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.9117, RMSE 0.0922
# [Open3D DEBUG] Residual : 6.02e-03 (# of elements : 201226)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.9131, RMSE 0.0912
# [Open3D DEBUG] Residual : 5.87e-03 (# of elements : 201515)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.9130, RMSE 0.0909
# [Open3D DEBUG] Residual : 5.84e-03 (# of elements : 201512)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.9132, RMSE 0.0909
# [Open3D DEBUG] Residual : 5.83e-03 (# of elements : 201538)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.9131, RMSE 0.0908
# [Open3D DEBUG] Residual : 5.82e-03 (# of elements : 201536)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.9132, RMSE 0.0908
# [Open3D DEBUG] Residual : 5.82e-03 (# of elements : 201538)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.9132, RMSE 0.0908
# [Open3D DEBUG] Residual : 5.82e-03 (# of elements : 201541)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.9132, RMSE 0.0908
# [Open3D DEBUG] Residual : 5.82e-03 (# of elements : 201541)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.9132, RMSE 0.0908
# [Open3D DEBUG] Residual : 5.82e-03 (# of elements : 201543)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.9132, RMSE 0.0908
# [Open3D DEBUG] Residual : 5.82e-03 (# of elements : 201543)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.2764, RMSE 0.0190
# [Open3D DEBUG] Residual : 1.98e-04 (# of elements : 61002)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.2976, RMSE 0.0181
# [Open3D DEBUG] Residual : 1.68e-04 (# of elements : 65683)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.3017, RMSE 0.0173
# [Open3D DEBUG] Residual : 1.39e-04 (# of elements : 66581)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.3023, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.29e-04 (# of elements : 66714)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.3020, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.26e-04 (# of elements : 66660)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.3020, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.26e-04 (# of elements : 66655)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.3020, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.26e-04 (# of elements : 66649)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.3019, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.26e-04 (# of elements : 66640)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.3021, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.26e-04 (# of elements : 66669)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.3020, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.26e-04 (# of elements : 66656)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.3021, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.26e-04 (# of elements : 66673)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.3021, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.26e-04 (# of elements : 66675)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.3022, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.26e-04 (# of elements : 66700)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.3022, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.26e-04 (# of elements : 66698)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.3022, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.26e-04 (# of elements : 66694)
# Build o3d.pipelines.registration.PoseGraph
# Apply point-to-plane ICP
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.9510, RMSE 0.0765
# [Open3D DEBUG] Residual : 3.25e-03 (# of elements : 209889)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.9512, RMSE 0.0694
# [Open3D DEBUG] Residual : 2.59e-03 (# of elements : 209939)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.9511, RMSE 0.0686
# [Open3D DEBUG] Residual : 2.54e-03 (# of elements : 209918)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.9511, RMSE 0.0684
# [Open3D DEBUG] Residual : 2.54e-03 (# of elements : 209902)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.9510, RMSE 0.0684
# [Open3D DEBUG] Residual : 2.54e-03 (# of elements : 209897)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.9510, RMSE 0.0684
# [Open3D DEBUG] Residual : 2.54e-03 (# of elements : 209897)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.4136, RMSE 0.0195
# [Open3D DEBUG] Residual : 2.13e-04 (# of elements : 91290)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.4254, RMSE 0.0182
# [Open3D DEBUG] Residual : 1.71e-04 (# of elements : 93889)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.4349, RMSE 0.0181
# [Open3D DEBUG] Residual : 1.70e-04 (# of elements : 95988)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.4453, RMSE 0.0181
# [Open3D DEBUG] Residual : 1.70e-04 (# of elements : 98289)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.4540, RMSE 0.0180
# [Open3D DEBUG] Residual : 1.69e-04 (# of elements : 100197)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.4595, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.66e-04 (# of elements : 101417)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.4626, RMSE 0.0177
# [Open3D DEBUG] Residual : 1.64e-04 (# of elements : 102088)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.4650, RMSE 0.0177
# [Open3D DEBUG] Residual : 1.64e-04 (# of elements : 102627)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.4660, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.63e-04 (# of elements : 102843)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.4666, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.62e-04 (# of elements : 102987)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.4670, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.61e-04 (# of elements : 103060)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.4672, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.61e-04 (# of elements : 103115)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.4673, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 103140)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.4675, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 103181)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.4675, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 103180)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.4676, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 103192)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.4675, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 103176)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.4673, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 103137)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.4672, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 103121)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.4671, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 103098)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.4671, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 103101)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.4673, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 103131)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.4674, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 103152)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.4674, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 103156)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.4675, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.59e-04 (# of elements : 103186)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.4677, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 103215)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.4677, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 103221)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.4677, RMSE 0.0177
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 103219)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.4676, RMSE 0.0177
# [Open3D DEBUG] Residual : 1.59e-04 (# of elements : 103200)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.4677, RMSE 0.0177
# [Open3D DEBUG] Residual : 1.59e-04 (# of elements : 103229)
# Build o3d.pipelines.registration.PoseGraph
# Apply point-to-plane ICP
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.7292, RMSE 0.1314
# [Open3D DEBUG] Residual : 1.34e-02 (# of elements : 160942)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.7826, RMSE 0.1262
# [Open3D DEBUG] Residual : 1.25e-02 (# of elements : 172721)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.7821, RMSE 0.1143
# [Open3D DEBUG] Residual : 9.59e-03 (# of elements : 172615)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.7803, RMSE 0.1109
# [Open3D DEBUG] Residual : 8.79e-03 (# of elements : 172206)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.7786, RMSE 0.1097
# [Open3D DEBUG] Residual : 8.50e-03 (# of elements : 171851)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.7772, RMSE 0.1090
# [Open3D DEBUG] Residual : 8.31e-03 (# of elements : 171522)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.7763, RMSE 0.1088
# [Open3D DEBUG] Residual : 8.25e-03 (# of elements : 171335)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.7755, RMSE 0.1086
# [Open3D DEBUG] Residual : 8.21e-03 (# of elements : 171153)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.7749, RMSE 0.1086
# [Open3D DEBUG] Residual : 8.20e-03 (# of elements : 171027)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.7744, RMSE 0.1085
# [Open3D DEBUG] Residual : 8.20e-03 (# of elements : 170910)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.7740, RMSE 0.1085
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170822)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.7736, RMSE 0.1084
# [Open3D DEBUG] Residual : 8.18e-03 (# of elements : 170745)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.7735, RMSE 0.1084
# [Open3D DEBUG] Residual : 8.18e-03 (# of elements : 170706)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.7733, RMSE 0.1085
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170679)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.7732, RMSE 0.1085
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170653)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.7731, RMSE 0.1085
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170632)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.7731, RMSE 0.1085
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170619)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.7730, RMSE 0.1085
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170604)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.7730, RMSE 0.1085
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170598)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.7729, RMSE 0.1084
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170587)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.7729, RMSE 0.1084
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170583)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.7729, RMSE 0.1084
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170580)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.7729, RMSE 0.1085
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170579)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.7729, RMSE 0.1085
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170577)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.7729, RMSE 0.1084
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170575)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.7729, RMSE 0.1084
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170572)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.7729, RMSE 0.1084
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170573)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.7728, RMSE 0.1084
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170571)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.7728, RMSE 0.1084
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170570)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.7728, RMSE 0.1084
# [Open3D DEBUG] Residual : 8.19e-03 (# of elements : 170570)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.1709, RMSE 0.0204
# [Open3D DEBUG] Residual : 2.52e-04 (# of elements : 37724)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.2036, RMSE 0.0190
# [Open3D DEBUG] Residual : 2.11e-04 (# of elements : 44936)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.2159, RMSE 0.0179
# [Open3D DEBUG] Residual : 1.73e-04 (# of elements : 47640)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.2194, RMSE 0.0180
# [Open3D DEBUG] Residual : 1.56e-04 (# of elements : 48419)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.2213, RMSE 0.0174
# [Open3D DEBUG] Residual : 1.50e-04 (# of elements : 48851)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.2222, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.47e-04 (# of elements : 49035)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.2225, RMSE 0.0174
# [Open3D DEBUG] Residual : 1.46e-04 (# of elements : 49104)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.2228, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.45e-04 (# of elements : 49165)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.2229, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.45e-04 (# of elements : 49205)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.2226, RMSE 0.0174
# [Open3D DEBUG] Residual : 1.44e-04 (# of elements : 49128)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.2226, RMSE 0.0173
# [Open3D DEBUG] Residual : 1.44e-04 (# of elements : 49131)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.2225, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.44e-04 (# of elements : 49103)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.2224, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.44e-04 (# of elements : 49086)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.2225, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.43e-04 (# of elements : 49097)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.2223, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.43e-04 (# of elements : 49052)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.2223, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.43e-04 (# of elements : 49061)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.2223, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.43e-04 (# of elements : 49061)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.2221, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.42e-04 (# of elements : 49022)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.2221, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.42e-04 (# of elements : 49018)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.2218, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.41e-04 (# of elements : 48963)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.2217, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.40e-04 (# of elements : 48940)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.2215, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.40e-04 (# of elements : 48881)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.2213, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.39e-04 (# of elements : 48851)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.2213, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.38e-04 (# of elements : 48831)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.2213, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.38e-04 (# of elements : 48835)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.2211, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.38e-04 (# of elements : 48803)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.2209, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.37e-04 (# of elements : 48760)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.2209, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.37e-04 (# of elements : 48752)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.2208, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.37e-04 (# of elements : 48742)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.2207, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.37e-04 (# of elements : 48719)
# Build o3d.pipelines.registration.PoseGraph
# Apply point-to-plane ICP
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.6158, RMSE 0.1318
# [Open3D DEBUG] Residual : 1.19e-02 (# of elements : 135909)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.6970, RMSE 0.1273
# [Open3D DEBUG] Residual : 1.21e-02 (# of elements : 153836)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.7265, RMSE 0.1133
# [Open3D DEBUG] Residual : 9.20e-03 (# of elements : 160347)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.7253, RMSE 0.1063
# [Open3D DEBUG] Residual : 7.63e-03 (# of elements : 160072)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.7233, RMSE 0.1046
# [Open3D DEBUG] Residual : 7.28e-03 (# of elements : 159640)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.7216, RMSE 0.1039
# [Open3D DEBUG] Residual : 7.14e-03 (# of elements : 159271)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.7204, RMSE 0.1035
# [Open3D DEBUG] Residual : 7.07e-03 (# of elements : 158996)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.7195, RMSE 0.1033
# [Open3D DEBUG] Residual : 7.03e-03 (# of elements : 158795)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.7189, RMSE 0.1032
# [Open3D DEBUG] Residual : 7.02e-03 (# of elements : 158663)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.7184, RMSE 0.1031
# [Open3D DEBUG] Residual : 7.01e-03 (# of elements : 158558)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.7180, RMSE 0.1031
# [Open3D DEBUG] Residual : 7.00e-03 (# of elements : 158469)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.7177, RMSE 0.1030
# [Open3D DEBUG] Residual : 6.99e-03 (# of elements : 158393)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.7175, RMSE 0.1030
# [Open3D DEBUG] Residual : 6.99e-03 (# of elements : 158347)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.7173, RMSE 0.1030
# [Open3D DEBUG] Residual : 6.99e-03 (# of elements : 158317)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.7172, RMSE 0.1030
# [Open3D DEBUG] Residual : 6.99e-03 (# of elements : 158296)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.7172, RMSE 0.1030
# [Open3D DEBUG] Residual : 6.99e-03 (# of elements : 158283)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.7171, RMSE 0.1030
# [Open3D DEBUG] Residual : 6.99e-03 (# of elements : 158272)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.7171, RMSE 0.1030
# [Open3D DEBUG] Residual : 6.99e-03 (# of elements : 158266)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.7171, RMSE 0.1030
# [Open3D DEBUG] Residual : 6.99e-03 (# of elements : 158265)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.7171, RMSE 0.1030
# [Open3D DEBUG] Residual : 6.99e-03 (# of elements : 158262)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.7171, RMSE 0.1030
# ...
# [Open3D DEBUG] Residual : 7.10e-03 (# of elements : 200637)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.1765, RMSE 0.0206
# [Open3D DEBUG] Residual : 3.07e-04 (# of elements : 36066)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.2183, RMSE 0.0183
# [Open3D DEBUG] Residual : 2.25e-04 (# of elements : 44607)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.2323, RMSE 0.0179
# [Open3D DEBUG] Residual : 2.05e-04 (# of elements : 47463)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.2415, RMSE 0.0181
# [Open3D DEBUG] Residual : 2.07e-04 (# of elements : 49332)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.2495, RMSE 0.0182
# [Open3D DEBUG] Residual : 2.07e-04 (# of elements : 50972)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.2579, RMSE 0.0182
# [Open3D DEBUG] Residual : 2.06e-04 (# of elements : 52693)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.2692, RMSE 0.0181
# [Open3D DEBUG] Residual : 2.06e-04 (# of elements : 55007)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.2828, RMSE 0.0181
# [Open3D DEBUG] Residual : 2.03e-04 (# of elements : 57781)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.2991, RMSE 0.0182
# [Open3D DEBUG] Residual : 2.02e-04 (# of elements : 61108)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.3136, RMSE 0.0180
# [Open3D DEBUG] Residual : 1.96e-04 (# of elements : 64078)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.3263, RMSE 0.0179
# [Open3D DEBUG] Residual : 1.94e-04 (# of elements : 66673)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.3383, RMSE 0.0178
# [Open3D DEBUG] Residual : 1.91e-04 (# of elements : 69125)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.3462, RMSE 0.0177
# [Open3D DEBUG] Residual : 1.83e-04 (# of elements : 70737)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.3516, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.77e-04 (# of elements : 71840)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.3551, RMSE 0.0174
# [Open3D DEBUG] Residual : 1.72e-04 (# of elements : 72539)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.3570, RMSE 0.0173
# [Open3D DEBUG] Residual : 1.69e-04 (# of elements : 72935)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.3583, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.66e-04 (# of elements : 73193)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.3589, RMSE 0.0172
# [Open3D DEBUG] Residual : 1.64e-04 (# of elements : 73330)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.3596, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.63e-04 (# of elements : 73460)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.3596, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.62e-04 (# of elements : 73465)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.3595, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.60e-04 (# of elements : 73448)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.3593, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.59e-04 (# of elements : 73396)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.3591, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.59e-04 (# of elements : 73373)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.3588, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.58e-04 (# of elements : 73306)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.3586, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.58e-04 (# of elements : 73271)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.3586, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.57e-04 (# of elements : 73256)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.3586, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.57e-04 (# of elements : 73264)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.3586, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.57e-04 (# of elements : 73257)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.3586, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.57e-04 (# of elements : 73254)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.3585, RMSE 0.0170
# [Open3D DEBUG] Residual : 1.57e-04 (# of elements : 73233)
# Build o3d.pipelines.registration.PoseGraph
# Apply point-to-plane ICP
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.7745, RMSE 0.1245
# [Open3D DEBUG] Residual : 1.20e-02 (# of elements : 177774)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.7890, RMSE 0.1043
# [Open3D DEBUG] Residual : 7.51e-03 (# of elements : 181119)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.7923, RMSE 0.1023
# [Open3D DEBUG] Residual : 7.06e-03 (# of elements : 181861)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.7931, RMSE 0.1017
# [Open3D DEBUG] Residual : 6.96e-03 (# of elements : 182053)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.7932, RMSE 0.1015
# [Open3D DEBUG] Residual : 6.93e-03 (# of elements : 182081)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.7933, RMSE 0.1014
# [Open3D DEBUG] Residual : 6.92e-03 (# of elements : 182103)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.7934, RMSE 0.1014
# [Open3D DEBUG] Residual : 6.92e-03 (# of elements : 182112)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.7934, RMSE 0.1013
# [Open3D DEBUG] Residual : 6.92e-03 (# of elements : 182117)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.7934, RMSE 0.1013
# [Open3D DEBUG] Residual : 6.92e-03 (# of elements : 182126)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.7935, RMSE 0.1013
# [Open3D DEBUG] Residual : 6.92e-03 (# of elements : 182131)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.7935, RMSE 0.1013
# [Open3D DEBUG] Residual : 6.92e-03 (# of elements : 182131)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.7935, RMSE 0.1013
# [Open3D DEBUG] Residual : 6.92e-03 (# of elements : 182136)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.7935, RMSE 0.1013
# [Open3D DEBUG] Residual : 6.92e-03 (# of elements : 182137)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.7935, RMSE 0.1013
# [Open3D DEBUG] Residual : 6.92e-03 (# of elements : 182137)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.7935, RMSE 0.1013
# [Open3D DEBUG] Residual : 6.92e-03 (# of elements : 182138)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.7935, RMSE 0.1013
# [Open3D DEBUG] Residual : 6.92e-03 (# of elements : 182138)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.7935, RMSE 0.1013
# [Open3D DEBUG] Residual : 6.92e-03 (# of elements : 182138)
# [Open3D DEBUG] ICP Iteration #0: Fitness 0.2019, RMSE 0.0192
# [Open3D DEBUG] Residual : 2.37e-04 (# of elements : 46350)
# [Open3D DEBUG] ICP Iteration #1: Fitness 0.2180, RMSE 0.0184
# [Open3D DEBUG] Residual : 2.10e-04 (# of elements : 50041)
# [Open3D DEBUG] ICP Iteration #2: Fitness 0.2209, RMSE 0.0177
# [Open3D DEBUG] Residual : 1.84e-04 (# of elements : 50702)
# [Open3D DEBUG] ICP Iteration #3: Fitness 0.2265, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.78e-04 (# of elements : 51987)
# [Open3D DEBUG] ICP Iteration #4: Fitness 0.2327, RMSE 0.0176
# [Open3D DEBUG] Residual : 1.74e-04 (# of elements : 53404)
# [Open3D DEBUG] ICP Iteration #5: Fitness 0.2387, RMSE 0.0175
# [Open3D DEBUG] Residual : 1.71e-04 (# of elements : 54788)
# [Open3D DEBUG] ICP Iteration #6: Fitness 0.2443, RMSE 0.0174
# [Open3D DEBUG] Residual : 1.67e-04 (# of elements : 56069)
# [Open3D DEBUG] ICP Iteration #7: Fitness 0.2487, RMSE 0.0173
# [Open3D DEBUG] Residual : 1.62e-04 (# of elements : 57078)
# [Open3D DEBUG] ICP Iteration #8: Fitness 0.2530, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.58e-04 (# of elements : 58070)
# [Open3D DEBUG] ICP Iteration #9: Fitness 0.2568, RMSE 0.0171
# [Open3D DEBUG] Residual : 1.54e-04 (# of elements : 58941)
# [Open3D DEBUG] ICP Iteration #10: Fitness 0.2599, RMSE 0.0169
# [Open3D DEBUG] Residual : 1.49e-04 (# of elements : 59667)
# [Open3D DEBUG] ICP Iteration #11: Fitness 0.2624, RMSE 0.0168
# [Open3D DEBUG] Residual : 1.44e-04 (# of elements : 60239)
# [Open3D DEBUG] ICP Iteration #12: Fitness 0.2634, RMSE 0.0167
# [Open3D DEBUG] Residual : 1.38e-04 (# of elements : 60469)
# [Open3D DEBUG] ICP Iteration #13: Fitness 0.2638, RMSE 0.0166
# [Open3D DEBUG] Residual : 1.33e-04 (# of elements : 60553)
# [Open3D DEBUG] ICP Iteration #14: Fitness 0.2637, RMSE 0.0166
# [Open3D DEBUG] Residual : 1.29e-04 (# of elements : 60532)
# [Open3D DEBUG] ICP Iteration #15: Fitness 0.2637, RMSE 0.0165
# [Open3D DEBUG] Residual : 1.28e-04 (# of elements : 60532)
# [Open3D DEBUG] ICP Iteration #16: Fitness 0.2638, RMSE 0.0165
# [Open3D DEBUG] Residual : 1.27e-04 (# of elements : 60549)
# [Open3D DEBUG] ICP Iteration #17: Fitness 0.2638, RMSE 0.0165
# [Open3D DEBUG] Residual : 1.26e-04 (# of elements : 60553)
# [Open3D DEBUG] ICP Iteration #18: Fitness 0.2637, RMSE 0.0164
# [Open3D DEBUG] Residual : 1.26e-04 (# of elements : 60541)
# [Open3D DEBUG] ICP Iteration #19: Fitness 0.2638, RMSE 0.0164
# [Open3D DEBUG] Residual : 1.26e-04 (# of elements : 60547)
# [Open3D DEBUG] ICP Iteration #20: Fitness 0.2637, RMSE 0.0164
# [Open3D DEBUG] Residual : 1.25e-04 (# of elements : 60527)
# [Open3D DEBUG] ICP Iteration #21: Fitness 0.2636, RMSE 0.0164
# [Open3D DEBUG] Residual : 1.25e-04 (# of elements : 60510)
# [Open3D DEBUG] ICP Iteration #22: Fitness 0.2635, RMSE 0.0164
# [Open3D DEBUG] Residual : 1.25e-04 (# of elements : 60495)
# [Open3D DEBUG] ICP Iteration #23: Fitness 0.2635, RMSE 0.0164
# [Open3D DEBUG] Residual : 1.25e-04 (# of elements : 60479)
# [Open3D DEBUG] ICP Iteration #24: Fitness 0.2635, RMSE 0.0164
# [Open3D DEBUG] Residual : 1.25e-04 (# of elements : 60487)
# [Open3D DEBUG] ICP Iteration #25: Fitness 0.2636, RMSE 0.0164
# [Open3D DEBUG] Residual : 1.25e-04 (# of elements : 60501)
# [Open3D DEBUG] ICP Iteration #26: Fitness 0.2636, RMSE 0.0164
# [Open3D DEBUG] Residual : 1.25e-04 (# of elements : 60511)
# [Open3D DEBUG] ICP Iteration #27: Fitness 0.2636, RMSE 0.0164
# [Open3D DEBUG] Residual : 1.25e-04 (# of elements : 60506)
# [Open3D DEBUG] ICP Iteration #28: Fitness 0.2636, RMSE 0.0164
# [Open3D DEBUG] Residual : 1.25e-04 (# of elements : 60516)
# [Open3D DEBUG] ICP Iteration #29: Fitness 0.2636, RMSE 0.0164
# [Open3D DEBUG] Residual : 1.25e-04 (# of elements : 60502)
# Build o3d.pipelines.registration.PoseGraph
# Optimizing PoseGraph ...
# [Open3D DEBUG] Validating PoseGraph - finished.
# [Open3D DEBUG] [GlobalOptimizationLM] Optimizing PoseGraph having 22 nodes and 231 edges.
# [Open3D DEBUG] Line process weight : 63.500252
# [Open3D DEBUG] [Initial     ] residual : 2.198796e+06, lambda : 1.900474e+02
# [Open3D DEBUG] [Iteration 00] residual : 1.304224e+04, valid edges : 0, time : 0.008 sec.
# [Open3D DEBUG] [Iteration 01] residual : 1.303246e+04, valid edges : 0, time : 0.001 sec.
# [Open3D DEBUG] [Iteration 02] residual : 1.303006e+04, valid edges : 0, time : 0.001 sec.
# [Open3D DEBUG] [Iteration 03] residual : 1.302937e+04, valid edges : 0, time : 0.001 sec.
# [Open3D DEBUG] [Iteration 04] residual : 1.302916e+04, valid edges : 0, time : 0.001 sec.
# [Open3D DEBUG] [Iteration 05] residual : 1.302908e+04, valid edges : 0, time : 0.001 sec.
# [Open3D DEBUG] [Iteration 06] residual : 1.302906e+04, valid edges : 0, time : 0.001 sec.
# [Open3D DEBUG] Current_residual - new_residual < 1.000000e-06 * current_residual
# [Open3D DEBUG] [GlobalOptimizationLM] total time : 0.014 sec.
# [Open3D DEBUG] [GlobalOptimizationLM] Optimizing PoseGraph having 22 nodes and 21 edges.
# [Open3D DEBUG] Line process weight : 61.654757
# [Open3D DEBUG] [Initial     ] residual : 4.649834e+01, lambda : 1.860091e+02
# [Open3D DEBUG] [Iteration 00] residual : 5.436169e-01, valid edges : 0, time : 0.000 sec.
# [Open3D DEBUG] [Iteration 01] residual : 1.049032e-02, valid edges : 0, time : 0.000 sec.
# [Open3D DEBUG] [Iteration 02] residual : 8.735736e-05, valid edges : 0, time : 0.000 sec.
# [Open3D DEBUG] [Iteration 03] residual : 1.735769e-07, valid edges : 0, time : 0.000 sec.
# [Open3D DEBUG] Current_residual < 1.000000e-06
# [Open3D DEBUG] [GlobalOptimizationLM] total time : 0.001 sec.
# [Open3D DEBUG] CompensateReferencePoseGraphNode : reference : 0
# Transform points and display
# [[ 1.00000000e+00 -9.52774842e-24  0.00000000e+00  0.00000000e+00]
#  [-9.30106135e-24  1.00000000e+00 -5.29395592e-23  0.00000000e+00]
#  [ 5.29395592e-23  5.29395592e-23  1.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# [[ 0.99957887 -0.02606855  0.01274812 -0.25205015]
#  [ 0.0259244   0.99959953  0.01134469 -0.06248995]
#  [-0.01303876 -0.01100942  0.99985438  0.26569656]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99977353 -0.02099224  0.00349415 -0.20434763]
#  [ 0.02095029  0.9997128   0.01163668 -0.05974645]
#  [-0.00373743 -0.01156084  0.99992619  0.25837067]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99978053 -0.01246983 -0.01683441  0.23048434]
#  [ 0.01274475  0.99978553  0.0163237  -0.1082041 ]
#  [ 0.01662725 -0.01653466  0.99972503  0.14655073]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99998095 -0.00148027 -0.00599204  0.00869857]
#  [ 0.00156395  0.99990099  0.01398414 -0.08594891]
#  [ 0.00597074 -0.01399324  0.99988426  0.13679913]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99954184 -0.01404681 -0.02681053  0.28657531]
#  [ 0.0148851   0.99939831  0.031328   -0.17244823]
#  [ 0.02635434 -0.03171272  0.99914951  0.16389259]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99964754 -0.01089557 -0.02420908  0.35711797]
#  [ 0.0113781   0.99973754  0.01988417 -0.07164057]
#  [ 0.02398608 -0.02015262  0.99950915  0.04417185]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99961274  0.00855644 -0.02647946  0.30148133]
#  [-0.00839217  0.99994489  0.00630841 -0.03660573]
#  [ 0.02653197 -0.00608375  0.99962945  0.1266911 ]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99972247 -0.0176605  -0.01559115  0.0932649 ]
#  [ 0.01799411  0.99960641  0.0215228  -0.09941277]
#  [ 0.01520491 -0.02179737  0.99964678  0.37745122]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99948751 -0.01471249 -0.02843006  0.12863532]
#  [ 0.01570905  0.99925844  0.03515375 -0.20361345]
#  [ 0.02789178 -0.03558234  0.99897745  0.42267783]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99938448 -0.01557005 -0.03143634  0.1691972 ]
#  [ 0.01631477  0.99958897  0.02357377 -0.12719609]
#  [ 0.03105637 -0.02407213  0.99922772  0.45109709]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99972815 -0.01376824 -0.01881662  0.08205366]
#  [ 0.01431249  0.99947396  0.02910238 -0.18093883]
#  [ 0.01840603 -0.02936378  0.99939931  0.3351903 ]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99890633 -0.00998431 -0.04567774  0.3325181 ]
#  [ 0.01041129  0.99990422  0.00911932 -0.02917568]
#  [ 0.04558231 -0.00958491  0.9989146   0.39769044]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99842384 -0.01172379 -0.05488523  0.50750351]
#  [ 0.01265893  0.99978005  0.01672139 -0.11015187]
#  [ 0.05467712 -0.01738982  0.99835265  0.4991281 ]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99832994 -0.02687372 -0.05113839  0.42021063]
#  [ 0.02759399  0.99952898  0.01343101 -0.09443417]
#  [ 0.05075336 -0.01481969  0.99860126  0.61028588]
#  [ 0.          0.          0.          1.        ]]
# [[ 9.98824454e-01 -9.84414958e-03 -4.74636926e-02  5.14696796e-01]
#  [ 9.82245550e-03  9.99951520e-01 -6.90287348e-04 -2.07979435e-02]
#  [ 4.74681868e-02  2.23265876e-04  9.98872725e-01  4.75994399e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# [[ 0.99843606 -0.01195469 -0.05461246  0.55716888]
#  [ 0.01156909  0.9999059  -0.00737151  0.03557084]
#  [ 0.05469544  0.00672817  0.99848042  0.4110728 ]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99844971 -0.00688213 -0.05523418  0.73047109]
#  [ 0.00676185  0.99997434 -0.00236422  0.02440485]
#  [ 0.05524904  0.00198707  0.99847063  0.45170183]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99911114 -0.00831442 -0.04132554  0.6580349 ]
#  [ 0.00947147  0.99956635  0.02788192 -0.15121219]
#  [ 0.0410758  -0.02824855  0.99875663  0.51622152]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99889933 -0.02046501 -0.04220561  0.57937172]
#  [ 0.02178645  0.99927909  0.03109105 -0.18094859]
#  [ 0.04153891 -0.03197634  0.99862507  0.71241028]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.99619694 -0.00483372 -0.08699595  1.18749607]
#  [ 0.00677424  0.99973448  0.02202442 -0.13132897]
#  [ 0.08686639 -0.02252999  0.99596518  0.76173256]
#  [ 0.          0.          0.          1.        ]]
# [[ 0.9981557  -0.00484137 -0.06051249  0.83008887]
#  [ 0.00619541  0.99973416  0.02220871 -0.16354489]
#  [ 0.06038888 -0.02254265  0.99792034  0.75326776]
#  [ 0.          0.          0.          1.        ]]

# %%
pcd_comb = copy.deepcopy(pcd1)
for pcd in sup_pcds:
    pcd_comb += pcd

# %%
depth_comb = create_depth_map(np.asarray(pcd_comb.points), torch_intrinsics1.squeeze().cpu().numpy(), (H,W))
depth_comb = cv2.medianBlur(depth_comb.astype('float32'), 5)

depth_col_avg = colorize_np(depth_comb, vmin=0.01, vmax=10.0, cmap="magma_r")
Image.fromarray(depth_col_avg).save("averaged4.png")

points_tensor = torch.tensor(np.asarray(pcd_comb.points), dtype=torch.float)
points_tensor = points_tensor.view(-1, 3).unsqueeze(0).cuda()
torch_depth = project_points(points_tensor, torch_intrinsics1, (H,W))
depth_pred_col = colorize(torch_depth.squeeze().cpu().numpy(), vmin=0.01, vmax=10.0, cmap="magma_r")
Image.fromarray(depth_pred_col).save("averaged.png")

point_cloud_flat = torch_points1.view(1, 3, -1)  # Shape: (B, 3, HW)
point_cloud_transposed = point_cloud_flat.transpose(1, 2)  # Shape: (B, HW, 3)
torch_depth = project_points(point_cloud_transposed, torch_intrinsics1, (H,W))
depth_pred_col = colorize(torch_depth.squeeze().cpu().numpy(), vmin=0.01, vmax=10.0, cmap="magma_r")
Image.fromarray(depth_pred_col).save("original.png")

# %%
model = UniDepthV1.from_pretrained("lpiccinelli/unidepth-v1-vitl14")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

img1 = kornia.io.load_image('pair2/im0.png', kornia.io.ImageLoadType.RGB32)[None, ...]
img2 = kornia.io.load_image('pair2/im1.png', kornia.io.ImageLoadType.RGB32)[None, ...]
    
_ , _ , H,W = img1.size()

T, torch_intrinsics1, torch_points1 = pairwise_pose(img1,img2, model)
pcd1 = o3d.io.read_point_cloud("ply2/im1.ply")
pcd2 = o3d.io.read_point_cloud("ply2/im2.ply")
pcd2 = pcd2.transform(T)


""" voxel_size = 0.1

source_down, source_fpfh = preprocess_point_cloud(pcd2, voxel_size)
target_down, target_fpfh = preprocess_point_cloud(pcd1, voxel_size)

result_ransac = execute_global_registration(source_down, target_down,
                                            source_fpfh, target_fpfh,
                                            voxel_size)

pcd2 = pcd2.transform(result_ransac.transformation)  """

o3d.io.write_point_cloud("ply2/im2new.ply", pcd2)

pcd_comb = pcd1 + pcd2

points = np.asarray(pcd_comb.points)
points_tensor = torch.tensor(points, dtype=torch.float)
points_tensor = points_tensor.view(-1, 3).unsqueeze(0).cuda()
depth = project_points(points_tensor, torch_intrinsics1, (H,W))
depth_pred_col = colorize(depth.squeeze().cpu().numpy(), vmin=0.01, vmax=10.0, cmap="magma_r")
Image.fromarray(depth_pred_col).save("averaged.png")

point_cloud_flat = torch_points1.view(1, 3, -1)  # Shape: (B, 3, HW)
point_cloud_transposed = point_cloud_flat.transpose(1, 2)  # Shape: (B, HW, 3)
depth = project_points(point_cloud_transposed, torch_intrinsics1, (H,W))
depth_pred_col = colorize(depth.squeeze().cpu().numpy(), vmin=0.01, vmax=10.0, cmap="magma_r")
Image.fromarray(depth_pred_col).save("original.png")



""" points = np.asarray(pcd_comb.points)
points_tensor = torch.tensor(points, dtype=torch.float)
points_tensor = points_tensor.view(-1, 3).unsqueeze(0).cuda()
torch_depth = project_points(points_tensor, torch_intrinsics1, (H,W))
depth_pred_col = colorize(torch_depth.squeeze().cpu().numpy(), vmin=0.01, vmax=10.0, cmap="magma_r")
Image.fromarray(depth_pred_col).save("averaged.png")

point_cloud_flat = torch_points1.view(1, 3, -1)  # Shape: (B, 3, HW)
point_cloud_transposed = point_cloud_flat.transpose(1, 2)  # Shape: (B, HW, 3)
torch_depth = project_points(point_cloud_transposed, torch_intrinsics1, (H,W))
depth_pred_col = colorize(torch_depth.squeeze().cpu().numpy(), vmin=0.01, vmax=10.0, cmap="magma_r")
Image.fromarray(depth_pred_col).save("original.png") """


""" depth = create_depth_map(np.asarray(pcd1.points), intrinsics1.squeeze().cpu().numpy(), (H,W))
depth_comb = create_depth_map(np.asarray(pcd_comb.points), intrinsics1.squeeze().cpu().numpy(), (H,W))

plt.imshow(depth, cmap='jet')
plt.colorbar()
plt.title('Depth Map')
plt.savefig('depth.png') 
plt.clf()

plt.imshow(depth_comb, cmap='jet')
plt.colorbar()
plt.title('Depth Map')
plt.savefig('depth_avg.png') 
plt.clf() """

""" points = np.asarray(pcd_comb.points)
points_tensor = torch.tensor(points, dtype=torch.float)
points_tensor = points_tensor.view(-1, 3).unsqueeze(0).cuda()

#print(points_tensor)
depth = project_points(points_tensor, intrinsics1, (H,W))
print(depth.shape)
depth_pred_col = colorize(depth.squeeze().cpu().numpy(), vmin=0.01, vmax=10.0, cmap="magma_r")
Image.fromarray(depth_pred_col).save("averaged.png")
 """
# Out:
# Instantiate: dinov2_vitl14
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 10
#       6 img2 = kornia.io.load_image('pair2/im1.png', kornia.io.ImageLoadType.RGB32)[None, ...]
#       8 _ , _ , H,W = img1.size()
# ---> 10 T, torch_intrinsics1, torch_points1 = pairwise_pose(img1,img2, model)
#      11 pcd1 = o3d.io.read_point_cloud("ply2/im1.ply")
#      12 pcd2 = o3d.io.read_point_cloud("ply2/im2.ply")
#
# Cell In[33], line 3, in pairwise_pose(img1_path, img2_path, model)
#       1 def pairwise_pose(img1_path, img2_path, model):
# ----> 3     img1 = kornia.io.load_image(img1_path, kornia.io.ImageLoadType.RGB32)[None, ...]
#       4     img2 = kornia.io.load_image(img2_path, kornia.io.ImageLoadType.RGB32)[None, ...]
#       5     matcher = kornia.feature.LoFTR(pretrained="indoor")
#
# File ~/miniconda3/envs/unidepth/lib/python3.10/site-packages/kornia/io/io.py:80, in load_image(path_file, desired_type, device)
#      69 """Read an image file and decode using the Kornia Rust backend.
#      70
#      71 Args:
#    (...)
#      77     Image tensor with shape :math:`(3,H,W)`.
#      78 """
#      79 if not isinstance(path_file, Path):
# ---> 80     path_file = Path(path_file)
#      82 # read the image using the kornia_rs package
#      83 image: Tensor = _load_image_to_tensor(path_file, device)  # CxHxW
#
# File ~/miniconda3/envs/unidepth/lib/python3.10/pathlib.py:960, in Path.__new__(cls, *args, **kwargs)
#     958 if cls is Path:
#     959     cls = WindowsPath if os.name == 'nt' else PosixPath
# --> 960 self = cls._from_parts(args)
#     961 if not self._flavour.is_supported:
#     962     raise NotImplementedError("cannot instantiate %r on your system"
#     963                               % (cls.__name__,))
#
# File ~/miniconda3/envs/unidepth/lib/python3.10/pathlib.py:594, in PurePath._from_parts(cls, args)
#     589 @classmethod
#     590 def _from_parts(cls, args):
#     591     # We need to call _parse_args on the instance, so as to get the
#     592     # right flavour.
#     593     self = object.__new__(cls)
# --> 594     drv, root, parts = self._parse_args(args)
#     595     self._drv = drv
#     596     self._root = root
#
# File ~/miniconda3/envs/unidepth/lib/python3.10/pathlib.py:578, in PurePath._parse_args(cls, args)
#     576     parts += a._parts
#     577 else:
# --> 578     a = os.fspath(a)
#     579     if isinstance(a, str):
#     580         # Force-cast str subclasses to str (issue #21127)
#     581         parts.append(str(a))
#
# TypeError: expected str, bytes or os.PathLike object, not Tensor
